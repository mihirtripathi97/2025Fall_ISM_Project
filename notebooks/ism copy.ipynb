# %% [markdown]
# ## Step1: Import Data

# %%
import os 
import sys
sys.path.append(os.path.abspath("../src"))
from jwst_utils.utils import *
import glob
# %matplotlib widget

# %%
# Data Preparation


data_dir = os.path.abspath("../data/jwst-tmc1a/")
print(data_dir)
print(os.path.exists(data_dir))
file_list = glob.glob(os.path.join(data_dir, "*.fits"))
file_list = [os.path.basename(f) for f in file_list]

print(file_list )
data_dict = create_data_dict(file_list, data_dir = data_dir, check_header= True, check_file_header='TMC1A_g140h-f100lp_s3d.fits')
# 'TMC1A_g235h.x1d', 'TMC1A_g140h.x1d', 'TMC1A_g140h.s3d', 'TMC1A_g395h.x1d', 'TMC1A_g235h.s3d', 'TMC1A_g395h.s3d'
# Out:
# /Users/tripathimihir/Documents/Coursework/ISM/Project/2025 ISM Final Project/2025Fall_ISM_Project/data/jwst-tmc1a
# True
# ['TMC1A_g140h-f100lp_s3d.fits', 'TMC1A_g235h-f170lp_x1d.fits', 'TMC1A_g395h-f290lp_x1d.fits', 'TMC1A_g395h-f290lp_s3d.fits', 'TMC1A_g140h-f100lp_x1d.fits', 'TMC1A_g235h-f170lp_s3d.fits']
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    3 / number of array dimensions
# NAXIS1  =                   53
# NAXIS2  =                   55
# NAXIS3  =                 3915
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# EXTNAME = 'SCI     '           / extension name
# SRCTYPE = 'EXTENDED'           / Source type used for calibration
# MJD-BEG =    59824.70809917824 / [d] exposure start time in MJD
# MJD-AVG =    59824.75615017361 / [d] exposure mid-point in MJD
# MJD-END =   59824.804159074076 / [d] exposure end time in MJD
# TDB-BEG =    59824.70865651518 / [d] TDB time of exposure start in MJD
# TDB-MID =   59824.756712287555 / [d] TDB time of exposure mid-point in MJD
# TDB-END =      59824.804725961 / [d] TDB time of exposure end in MJD
# XPOSURE =   15460.944000000001 / [s] Effective exposure time
# TELAPSE =   15718.632000000001 / [s] Total elapsed exposure time
#
#         JWST ephemeris information
#
# REFFRAME= 'EME2000 '           / Ephemeris reference frame (EME2000)
# EPH_TYPE= 'Definitive'         / Definitive or Predicted
# EPH_TIME=   59824.715680277775 / [d] MJD time of position and velocity vectors
# JWST_X  =   141377349.91368648 / [km] barycentric JWST X coordinate at MJD-AVG
# JWST_Y  =   -48446337.39792639 / [km] barycentric JWST Y coordinate at MJD-AVG
# JWST_Z  =  -20935574.570032764 / [km] barycentric JWST Z coordinate at MJD-AVG
# OBSGEO-X=    979945562.3046088 / [m] geocentric JWST X coordinate at MJD-AVG
# OBSGEO-Y=  -1034016325.4649061 / [m] geocentric JWST Y coordinate at MJD-AVG
# OBSGEO-Z=  -414818132.24136496 / [m] geocentric JWST Z coordinate at MJD-AVG
# JWST_DX =    9.920688189975442 / [km/s] barycentric JWST X velocity at MJD-AVG
# JWST_DY =     25.7713768408512 / [km/s] barycentric JWST Y velocity at MJD-AVG
# JWST_DZ =   11.353343648374976 / [km/s] barycentric JWST Z velocity at MJD-AVG
# OBSGEODX=    184.9201026336602 / [m/s] geocentric JWST X velocity at MJD-AVG
# OBSGEODY=   215.19316109894632 / [m/s] geocentric JWST Y velocity at MJD-AVG
# OBSGEODZ=    273.6312281977459 / [m/s] geocentric JWST Z velocity at MJD-AVG
# PA_APER =   41.217038123024466 / [deg] Position angle of aperture used
# VA_SCALE=   1.0000994182600331 / Velocity aberration scale factor
# BUNIT   = 'MJy/sr  '           / physical units of the array values
#
#         Photometry information
#
# PHOTMJSR=      3837608329216.0 / Flux density (MJy/steradian) producing 1 cps
# PHOTUJA2=     90200797609984.0 / Flux density (uJy/arcsec2) producing 1 cps
# PIXAR_SR= 2.35040007004737E-13 / Nominal pixel area in steradians
# PIXAR_A2= 0.010000000298023226 / Nominal pixel area in arcsec^2
#
#         Information about the coordinates in the file
#
# RADESYS = 'ICRS    '           / Name of the coordinate reference frame
#
#         Spacecraft pointing information
#
# RA_V1   =    69.75698568488069 / [deg] RA of telescope V1 axis
# DEC_V1  =   25.594389195528482 / [deg] Dec of telescope V1 axis
# PA_V3   =    262.1848972040962 / [deg] Position angle of telescope V3 axis
#
#         WCS parameters
#
# WCSAXES =                    3 / number of World Coordinate System axes
# CRPIX1  =                 27.0 / Axis 1 pixel coordinate of ref point, 1-indexed
# CRPIX2  =                 28.0 / Axis 2 pixel coordinate of ref point, 1-indexed
# CRPIX3  =                  1.0 / Axis 3 pixel coordinate of ref point, 1-indexed
# CRVAL1  =         69.896653292 / Axis 1 coordinate value at reference point
# CRVAL2  =        25.6956279295 / Axis 2 coordinate value at reference point
# CRVAL3  =   0.9701175286099897 / Axis 3 coordinate value at reference point
# CTYPE1  = 'RA---TAN'           / Axis 1 type
# CTYPE2  = 'DEC--TAN'           / Axis 2 type
# CTYPE3  = 'WAVE    '           / Axis 3 type
# CUNIT1  = 'deg     '           / Axis 1 units
# CUNIT2  = 'deg     '           / Axis 2 units
# CUNIT3  = 'um      '           / Axis 3 units
# CDELT1  = 2.77777781916989E-05 / Axis 1 coordinate increment at reference point
# CDELT2  = 2.77777781916989E-05 / Axis 2 coordinate increment at reference point
# CDELT3  = 0.000234999999520368 / Axis 3 coordinate increment at reference point
# PC1_1   =                 -1.0 / Linear transformation matrix element
# PC1_2   =                  0.0 / Linear transformation matrix element
# PC1_3   =                    0 / Linear transformation matrix element
# PC2_1   =                  0.0 / Linear transformation matrix element
# PC2_2   =                  1.0 / Linear transformation matrix element
# PC2_3   =                    0 / Linear transformation matrix element
# PC3_1   =                    0 / Linear transformation matrix element
# PC3_2   =                    0 / Linear transformation matrix element
# PC3_3   =                    1 / Linear transformation matrix element
# S_REGION= 'POLYGON ICRS  69.895851806 25.694877927 69.895851806 25.696377927 &'
# CONTINUE  '69.897454778 25.696377927 69.897454778 25.694877927&'
# CONTINUE  '' / spatial extent of the observation, footprint
# WAVSTART=              9.7E-07 / Lower bound of the default wavelength range
# WAVEND  =             1.89E-06 / Upper bound of the default wavelength range
# DISPAXIS=                    1 / Dispersion direction
# SPORDER =                   -1 / Spectral order number
# VELOSYS =            -29803.25 / [m/s] Barycentric correction to radial velocity
# SPECSYS = 'BARYCENT'           / Spectral reference frame
# EXTVER  =                    1 / extension value
# data_dict keys: dict_keys(['TMC1A_g140h.s3d', 'TMC1A_g235h.x1d', 'TMC1A_g395h.x1d', 'TMC1A_g395h.s3d', 'TMC1A_g140h.x1d', 'TMC1A_g235h.s3d'])

# %% [markdown]
# ## Step2: Overview the image and spectrum

# %%
# Plot the raw image, g140 
g140_s3d = data_dict['TMC1A_g140h.s3d']['data']
pixel = data_dict['TMC1A_g140h.s3d']['header']['CDELT1']*3600 # change the pixel unit  qfrom deg to arcsec
#print(pixel)
plot_image(g140_s3d[2855], data_dict['TMC1A_g140h.s3d']['header'], vmin = -1, vmax = 1e3, a = 1e-2, text = '-70km/s', savefig = False, save_name = 'g140_2865.png')

# Fe II 1.644: line center is at 2866
# HI Brackett-12 (1.6412) is at 2855
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Plot the spectrum without conntinuum subtraction, g140
wave, flux = calc_spec(g140_s3d, header = data_dict['TMC1A_g140h.s3d']['header'])
# Out:
# Sr in pixel: 2.3504431239584476e-13
# Begin to calculate spectrum flux without continuum subtraction...
# Calculating spectrum flux:   0%|          | 0/3915 [00:00<?, ?it/s]0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Calculating spectrum flux: 100%|██████████| 3915/3915 [00:04<00:00, 839.01it/s]
# Finish calculate spectrum flux without continuum subtraction!!
# Return the wave and flux arrays.

# %%
data = g140_s3d
plot_line_spectrum(wave, data_dict['TMC1A_g140h.s3d']['header'], flux, xlim = (-1800,1800), 
                   ylim = (-2e-3, 2e-2), text = ('1.644', 'FeII'), restwave = 1.644, savefig = False, 
                   save_name = 'FeII1644_spectrum.png', plot_all_spec= True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Step3: Continuum subtraction using Sagov-filter
# The method is based on JDISC program and ctool (https://github.com/pontoppi/ctool). After that we will correct the radial velocity.

# %% [markdown]
# ### Explanation of Continuum Subtraction Process
# The `calc_cont` function implements a robust method for continuum subtraction using median filtering and anchor points. Here's how it works:
#
# 1. **Median Filter**:
#    - Uses `medfilt` with a specified box size (default=101)
#    - Smooths the data by replacing each point with the median of its surrounding points
#    - Helps remove noise while preserving sharp spectral features
#
# 2. **Anchor Points Selection**:
#    - Identifies reliable continuum points using a threshold (default=0.998)
#    - Points where smoothed flux > original flux × threshold become anchor points
#    - If too few anchors found (< 2), relaxes threshold to 0.99
#    - If still insufficient, falls back to using smoothed data
#
# 3. **Continuum Estimation**:
#    - Uses linear interpolation between anchor points
#    - Preserves the actual continuum shape without being affected by emission/absorption lines
#    - Iterative process refines the estimate over multiple passes
#
# 4. **Final Smoothing**:
#    - Applies Savitzky-Golay filter for final smoothing
#    - Window size = 3 × boxsize
#    - Uses first-order polynomial fit
#
# This method is particularly effective because:
# - Median filtering preserves sharp features
# - Anchor points ensure we're using reliable continuum regions
# - Interpolation helps avoid contamination from spectral lines
# - Multiple iterations help refine the final result
#
# This work is totally based on the ctool package.

# %%
# From previous result we can see that there are lots of bad pixel, so we first need to use shift coordinat and continuum subtraction
# Reminder: g140_s3d is the original data cube
import bettermoments as bm
from tqdm.notebook import tqdm
cont_spaxel, line_spaxel = generate_line_cont(data, wave, boxsize= 13 )
# Out:
# Generating continuum and line emission cubes: 100%|██████████| 55/55 [00:00<00:00, 66.31it/s]

# %%
print(type(line_spaxel))
# Out:
# <class 'numpy.ndarray'>

# %%
# Plot the continuum emission of the FeII 1.644
plot_image(line_spaxel[2868], data_dict['TMC1A_g140h.s3d']['header'], vmin = -1, vmax = 1e3, a = 1e-2, text = '-70km/s', savefig = False, save_name = 'line_2866.png')
plot_image(cont_spaxel[2878], data_dict['TMC1A_g140h.s3d']['header'], vmin = -1, vmax = 1e3, a = 1e-2, text = '-70km/s', savefig = False, save_name = 'cont_2866.png')
# Out:
# ERROR:tornado.general:SEND Error: Host unreachable
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Plot the continuum emission of the FeII 1.644
# ----> 2 plot_image(line_spaxel[2868], data_dict['TMC1A_g140h.s3d']['header'], vmin = -1, vmax = 1e3, a = 1e-2, text = '-70km/s', savefig = False, save_name = 'line_2866.png')
#       3 plot_image(cont_spaxel[2878], data_dict['TMC1A_g140h.s3d']['header'], vmin = -1, vmax = 1e3, a = 1e-2, text = '-70km/s', savefig = False, save_name = 'cont_2866.png')
#
# File <stringsource>:69, in cfunc.to_py.__Pyx_CFunc_b0409f__29_pydevd_sys_monitoring_cython_object__lParen__etc_to_py_4code_4line.wrap()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1481, in _pydevd_sys_monitoring_cython._line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1523, in _pydevd_sys_monitoring_cython._internal_line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1324, in _pydevd_sys_monitoring_cython._stop_on_breakpoint()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1961, in _pydevd_sys_monitoring_cython._do_wait_suspend()
#
# File ~/Documents/Coursework/ISM/Project/2025 ISM Final Project/2025Fall_ISM_Project/.venv/lib/python3.13/site-packages/debugpy/_vendored/pydevd/pydevd.py:2188, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2185             from_this_thread.append(frame_custom_thread_id)
#    2187     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2188         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2190 frames_list = None
#    2192 if keep_suspended:
#    2193     # This means that we should pause again after a set next statement.
#
# File ~/Documents/Coursework/ISM/Project/2025 ISM Final Project/2025Fall_ISM_Project/.venv/lib/python3.13/site-packages/debugpy/_vendored/pydevd/pydevd.py:2257, in PyDB._do_wait_suspend(self, thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2254                 queue.put(internal_cmd)
#    2255                 wait_timeout = TIMEOUT_FAST
# -> 2257         notify_event.wait(wait_timeout)
#    2258         notify_event.clear()
#    2260 finally:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/threading.py:659, in Event.wait(self, timeout)
#     657 signaled = self._flag
#     658 if not signaled:
# --> 659     signaled = self._cond.wait(timeout)
#     660 return signaled
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/threading.py:363, in Condition.wait(self, timeout)
#     361 else:
#     362     if timeout > 0:
# --> 363         gotit = waiter.acquire(True, timeout)
#     364     else:
#     365         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
# Plot the continuum emission of the FeII 1.644
plot_image(line_spaxel[2866], data_dict['TMC1A_g140h.s3d']['header'], vmin = -1, vmax = 1e3, a = 1e-2, text = r"1.644 $\mu$ m", savefig = False, save_name = 'line_2866.png')
#plot_image(cont_spaxel[2866], data_dict['TMC1A_g140h.s3d']['header'], vmin = -1, vmax = 1e3, a = 1e-2, text = '-70km/s', savefig = False, save_name = 'cont_2866.png')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Plot the continuum emission of the FeII 1.644
plot_image(line_spaxel[1219], data_dict['TMC1A_g140h.s3d']['header'], vmin = -1, vmax = 1e3, a = 1e-2, text = r'1.2566 $\mu$m', savefig = False, save_name = 'line_2866.png')
#plot_image(cont_spaxel[2866], data_dict['TMC1A_g140h.s3d']['header'], vmin = -1, vmax = 1e3, a = 1e-2, text = '-70km/s', savefig = False, save_name = 'cont_2866.png')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Plot the spectrum with conntinuum subtraction, g140
cont, flux_line = calc_contsubtract_spec(line_spaxel, cont_spaxel, header = data_dict['TMC1A_g140h.s3d']['header'])
# Out:
# Sr in pixel: 2.3504431239584476e-13
# Calculating spectrum flux with continuum subtraction: 100%|██████████| 3915/3915 [00:09<00:00, 421.55it/s]

# %%
v_1644 = optical_veocity(wave, data_dict['TMC1A_g140h.s3d']['header'])
# Plot the comparison between line and continuum emissions
plot_comparison_line_continuum(v_1644, wave, flux, flux_line, cont, plot_all_spec = True, savefig = False, save_name = 'Comparison_line_cont.png')

# %% [markdown]
# ### Note
# For Fe II boxsize =13 is enough but for larger wavelegnth we need to use other size of box size.

# %%
# Save the line data and continuum data in new fits file
import os
import astropy.io.fits as fits
# Create directory to save the new fits files

if not os.path.exists('FeII_subtract_continuum/'):
    os.mkdir('FeII_subtract_continuum/')
#os.chdir('subtract_continuum')
# export continuum as *_cont.fits
header = data_dict['TMC1A_g140h.s3d']['header']
hdu_new = fits.PrimaryHDU(data = cont_spaxel, header = header)
hdu_new.writeto('FeII_subtract_continuum/TMC1A_g140h.s3d'+'_cont.fits', overwrite=True)
# export continuum as *_line.fits
hdu_new = fits.PrimaryHDU(data = line_spaxel, header = header)
hdu_new.writeto('FeII_subtract_continuum/TMC1A_g140h.s3d'+'_line.fits', overwrite=True)

# %% [markdown]
# ## Step 4: Create Moment zero and one map by using bettermoments

# %%
# Generate Moment zero and one map of FeII 1.644 the line emission
filepath = '/Users/tripathimihir/Documents/Coursework/ISM/Project/2025 ISM Final Project/2025Fall_ISM_Project/notebooks/FeII_subtract_continuum'
os.chdir(filepath)


cont_data, cont_wave = bm.load_cube('TMC1A_g140h.s3d_line.fits')

# Decide the moment map region [w1:w2]

rms = bm.estimate_RMS(data=cont_data[2840:2885, 10:15, 24:34 ], N=10) # set it in a line free region
print('RMS = {:.1f} mJy/beam (original)'.format(rms ))

w1, w2 = 2860, 2870
cont_data = cont_data[w1:w2]
cont_wave = cont_wave[w1:w2]
cont_vel = optical_veocity(cont_wave, w1644_rest)

user_mask = bm.get_user_mask(data= cont_data, user_mask_path=None)

threshold_mask = bm.get_threshold_mask(data= cont_data,
                                       clip= 1,
                                       smooth_threshold_mask=0.0)

channel_mask = bm.get_channel_mask(data = cont_data,
                                   firstchannel = 0,
                                   lastchannel = -1)

mask = bm.get_combined_mask(user_mask = user_mask, threshold_mask = threshold_mask, channel_mask = channel_mask, combine = 'and')
masked_data = cont_data *mask

moments = bm.collapse_zeroth(velax= cont_vel, data= masked_data, rms= rms)
bm.save_to_FITS(moments = moments, method= 'zeroth', path= filepath+"TMC1A_g140h.s3d_line.fits")

moments = bm.collapse_first(velax= cont_vel, data= masked_data, rms= rms)
bm.save_to_FITS(moments = moments, method= 'first', path= filepath+"TMC1A_g140h.s3d_line.fits")
# Out:
# RMS = 0.5 mJy/beam (original)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 16
#      14 cont_data = cont_data[w1:w2]
#      15 cont_wave = cont_wave[w1:w2]
# ---> 16 cont_vel = optical_veocity(cont_wave, w1644_rest)
#      18 user_mask = bm.get_user_mask(data= cont_data, user_mask_path=None)
#      20 threshold_mask = bm.get_threshold_mask(data= cont_data,
#      21                                        clip= 1,
#      22                                        smooth_threshold_mask=0.0)
#
# NameError: name 'w1644_rest' is not defined

# %%
# Read the continuum moment 0 map
filepath = '/Users/tripathimihir/Documents/Coursework/ISM/Project/2025 ISM Final Project/2025Fall_ISM_Project/notebooks/FeII_subtract_continuum'
os.chdir(filepath)

fitls = glob.glob('*.fits')
subcont_dict = {}
for i in fitls:
    hdul = fits.open(i)
    header = hdul[0].header
    data = hdul[0].data
    name = i.split('.')[0] +'.' + i.split('.')[1]
    subcont_dict['%s' %(name)] = {'header': header, 'data': data}
print(subcont_dict.keys())
# dict_keys(['TMC1A_g140h.s3d_line', 'TMC1A_g140h.s3d_cont_dM0', 'TMC1A_g140h.s3d_cont_M0', 'TMC1A_g140h.s3d_cont'])
# Out:
# dict_keys(['TMC1A_g140h.s3d_line', 'TMC1A_g140h.s3d_cont'])

# %%
# Plot the Moment zero map of 1.644 line
g140_s3d_lint_M0 = subcont_dict['TMC1A_g140h.s3d_line_M0']['data']
pixel = subcont_dict['TMC1A_g140h.s3d_line_M0']['header']['CDELT1']*3600 # change the pixel unit  qfrom deg to arcsec

def axis_transfer(pos,val):
    return f'{pos*pixel:.2f}'

fig = plt.figure(figsize = (8,10))

widths = [0.05,1]
heights = [0.05,1]
gs = fig.add_gridspec(2, 2, width_ratios=widths,height_ratios=heights)
gs.update(left=0.05, right=0.95, bottom=0.08, top=0.85, wspace=0.02, hspace=0.02)

ax1 = fig.add_subplot(gs[1,1])
cbar1 = fig.add_subplot(gs[0,1])
norm1 = ImageNormalize(g140_s3d_lint_M0, vmin= -1, vmax = 1e5, stretch=AsinhStretch(a=1e-2))
plt1 = ax1.imshow(g140_s3d_lint_M0, norm = norm1, cmap= 'inferno', origin = 'lower')
cb1 = Colorbar(ax = cbar1, mappable = plt1, orientation = 'horizontal', ticklocation = 'top', ticks = [0, 1e3, 1e4, 5e4, 1e5])

ax1.xaxis.set_major_formatter(FuncFormatter(axis_transfer))
ax1.yaxis.set_major_formatter(FuncFormatter(axis_transfer))
ax1.set_xlabel(r'$\Delta \alpha$' +' [arcsec]', fontsize = 15)
ax1.set_ylabel(r'$\Delta \delta$'+' [arcsec]',fontsize = 15)
ax1.text(0.05,0.95, 'FeII',transform=ax1.transAxes,fontsize = 15)
cbar1.set_title('MJy/Sr km/s',fontsize = 25, pad= 10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Plot the Moment zero map of 1.644 line
# ----> 2 g140_s3d_lint_M0 = subcont_dict['TMC1A_g140h.s3d_line_M0']['data']
#       3 pixel = subcont_dict['TMC1A_g140h.s3d_line_M0']['header']['CDELT1']*3600 # change the pixel unit  qfrom deg to arcsec
#       5 def axis_transfer(pos,val):
#
# KeyError: 'TMC1A_g140h.s3d_line_M0'

# %%
# Plot the Moment one map of 1.644 line
g140_s3d_line_M1 = subcont_dict['TMC1A_g140h.s3d_line_M1']['data']
pixel = subcont_dict['TMC1A_g140h.s3d_line_M1']['header']['CDELT1']*3600 # change the pixel unit  qfrom deg to arcsec

def axis_transfer(pos,val):
    return f'{pos*pixel:.2f}'

fig = plt.figure(figsize = (8,10))

widths = [0.05,1]
heights = [0.05,1]
gs = fig.add_gridspec(2, 2, width_ratios=widths,height_ratios=heights)
gs.update(left=0.05, right=0.95, bottom=0.08, top=0.85, wspace=0.02, hspace=0.02)

ax1 = fig.add_subplot(gs[1,1])
cbar1 = fig.add_subplot(gs[0,1])
norm1 = ImageNormalize(g140_s3d_line_M1, vmin= -200, vmax = 200)
plt1 = ax1.imshow(g140_s3d_line_M1, norm = norm1, cmap= 'RdBu_r', origin = 'lower')
cb1 = Colorbar(ax = cbar1, mappable = plt1, orientation = 'horizontal', ticklocation = 'top')

ax1.xaxis.set_major_formatter(FuncFormatter(axis_transfer))
ax1.yaxis.set_major_formatter(FuncFormatter(axis_transfer))
ax1.set_xlabel(r'$\Delta \alpha$' +' [arcsec]', fontsize = 15)
ax1.set_ylabel(r'$\Delta \delta$'+' [arcsec]',fontsize = 15)
ax1.text(0.05,0.95, r'$1.644\mu m$',transform=ax1.transAxes,fontsize = 15)
cbar1.set_title('km/s',fontsize = 25, pad= 10)
# Out:
# Text(0.5, 1.0, 'km/s')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Generate Moment zero map of FeII 1.644 the continuum emission
filepath = '/media/kuo-jui/data/ISM_finalproject/subtract_continuum/'
os.chdir(filepath)


cont_data, cont_wave = bm.load_cube('TMC1A_g140h.s3d_cont.fits')

# Decide the moment map region [w1:w2]

rms = bm.estimate_RMS(data=cont_data[2840:2885, 10:15, 24:34 ], N=10) # set it in a line free region
print('RMS = {:.1f} mJy/beam (original)'.format(rms ))

w1, w2 = 2860, 2870
cont_data = cont_data[w1:w2]
cont_wave = cont_wave[w1:w2]
cont_vel = optical_veocity(cont_wave, w1644_rest)

user_mask = bm.get_user_mask(data= cont_data, user_mask_path=None)

threshold_mask = bm.get_threshold_mask(data= cont_data,
                                       clip= None,
                                       smooth_threshold_mask=0.0)

channel_mask = bm.get_channel_mask(data = cont_data,
                                   firstchannel = 0,
                                   lastchannel = -1)

mask = bm.get_combined_mask(user_mask = user_mask, threshold_mask = threshold_mask, channel_mask = channel_mask, combine = 'and')
masked_data = cont_data *mask

moments = bm.collapse_zeroth(velax= cont_vel, data= masked_data, rms= rms)
bm.save_to_FITS(moments = moments, method= 'zeroth', path= filepath+"TMC1A_g140h.s3d_line.fits")

#moments = bm.collapse_first(velax= cont_vel, data= masked_data, rms= rms)
#bm.save_to_FITS(moments = moments, method= 'first', path= filepath+"TMC1A_g140h.s3d_line.fits")

# Read the continuum moment 0 map
filepath = '/media/kuo-jui/data/ISM_finalproject/subtract_continuum/'
os.chdir(filepath)

fitls = glob.glob('*.fits')
subcont_dict = {}
for i in fitls:
    hdul = fits.open(i)
    header = hdul[0].header
    data = hdul[0].data
    name = i.split('.')[0] +'.' + i.split('.')[1]
    subcont_dict['%s' %(name)] = {'header': header, 'data': data}
print(subcont_dict.keys())
# dict_keys(['TMC1A_g140h.s3d_line', 'TMC1A_g140h.s3d_cont_dM0', 'TMC1A_g140h.s3d_cont_M0', 'TMC1A_g140h.s3d_cont'])
# Out:
# RMS = 0.2 mJy/beam (original)
# dict_keys(['TMC1A_g140h.s3d_line_M0', 'TMC1A_g140h.s3d_line', 'TMC1A_g140h.s3d_line_dM0', 'TMC1A_g140h.s3d_line_M1', 'TMC1A_g140h.s3d_cont_dM0', 'TMC1A_g140h.s3d_cont_M0', 'TMC1A_g140h.s3d_cont', 'TMC1A_g140h.s3d_line_dM1'])

# %%
# Plot the raw image, g140 
g140_s3d_cont_M0 = subcont_dict['TMC1A_g140h.s3d_cont_M0']['data']
pixel = subcont_dict['TMC1A_g140h.s3d_cont_M0']['header']['CDELT1']*3600 # change the pixel unit  qfrom deg to arcsec

def axis_transfer(pos,val):
    return f'{pos*pixel:.2f}'

fig = plt.figure(figsize = (8,10))

widths = [0.05,1]
heights = [0.05,1]
gs = fig.add_gridspec(2, 2, width_ratios=widths,height_ratios=heights)
gs.update(left=0.05, right=0.95, bottom=0.08, top=0.85, wspace=0.02, hspace=0.02)

ax1 = fig.add_subplot(gs[1,1])
cbar1 = fig.add_subplot(gs[0,1])
norm1 = ImageNormalize(g140_s3d_cont_M0, vmin= -1, vmax = 5e5, stretch=AsinhStretch(a=5e-3))
plt1 = ax1.imshow(g140_s3d_cont_M0, norm = norm1, cmap= 'inferno', origin = 'lower')
cb1 = Colorbar(ax = cbar1, mappable = plt1, orientation = 'horizontal', ticklocation = 'top', ticks = [0, 1e3, 1e4, 5e4, 5e5])

ax1.xaxis.set_major_formatter(FuncFormatter(axis_transfer))
ax1.yaxis.set_major_formatter(FuncFormatter(axis_transfer))
ax1.set_xlabel(r'$\Delta \alpha$' +' [arcsec]', fontsize = 15)
ax1.set_ylabel(r'$\Delta \delta$'+' [arcsec]',fontsize = 15)
ax1.text(0.05,0.95, 'FeII',transform=ax1.transAxes,fontsize = 15)
cbar1.set_title('MJy/Sr km/s',fontsize = 25, pad= 10)
# Out:
# Text(0.5, 1.0, 'MJy/Sr km/s')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
